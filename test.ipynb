# %%
import visualization_old as vis

# %load_ext autoreload
# %autoreload 2
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
vis.plot_feature_histogram(pcd_path="/home/ben/Desktop/LRZ Sync+Share/Thesis/Data/samples/FAUST_smpl_template_000/sample_e40_n300000.ply")

# %%
vis.plot_mesh_vertices_histogram(mesh_path='/home/ben/Desktop/LRZ Sync+Share/Thesis/Data/data/MPI-FAUST/training/registrations/tr_reg_000.ply')
